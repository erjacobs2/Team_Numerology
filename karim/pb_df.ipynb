# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("lead_under_six.csv")
df
len(df)
# Out:
# 631

# %%
df.columns
# Out:
# Index(['indicator', 'year', 'location', 'ageGroup', 'ebllDescription',
#        'pctEbll', 'fips', 'numTested', 'numEbll', 'denominator', 'pctTested',
#        'unstable', 'Unnamed: 12'],
#       dtype='object')

# %%
rdf = df.loc[:, ['year', 'location', 'ageGroup', 'ebllDescription',
       'pctEbll',  'numTested', 'numEbll', 'denominator', 'pctTested',
       'unstable']]
rdf.head()
# Out:
#      year   location  ageGroup                      ebllDescription pctEbll  \
# 0  2011.0  Minnesota  <6 years  >5 mcg/dL (current reference level)     1.0
# 1  2012.0  Minnesota  <6 years  >5 mcg/dL (current reference level)     1.2
# 2  2013.0  Minnesota  <6 years  >5 mcg/dL (current reference level)     1.0
# 3  2014.0  Minnesota  <6 years  >5 mcg/dL (current reference level)     0.8
# 4  2015.0  Minnesota  <6 years  >5 mcg/dL (current reference level)     0.9
#
#    numTested  numEbll  denominator  pctTested unstable
# 0    91344.0    926.0     425252.0       21.5    False
# 1    90585.0   1063.0     422537.0       21.4    False
# 2    89488.0    866.0     420715.0       21.3    False
# 3    89060.0    730.0     419965.0       21.2    False
# 4    87717.0    781.0     421429.0       20.8    False

# %%
rrdf = rdf.loc[rdf["unstable"] ==False]
rrdf
# Out:
#        year    location  ageGroup                      ebllDescription  \
# 0    2011.0   Minnesota  <6 years  >5 mcg/dL (current reference level)
# 1    2012.0   Minnesota  <6 years  >5 mcg/dL (current reference level)
# 2    2013.0   Minnesota  <6 years  >5 mcg/dL (current reference level)
# 3    2014.0   Minnesota  <6 years  >5 mcg/dL (current reference level)
# 4    2015.0   Minnesota  <6 years  >5 mcg/dL (current reference level)
# 5    2016.0   Minnesota  <6 years  >5 mcg/dL (current reference level)
# 6    2017.0   Minnesota  <6 years  >5 mcg/dL (current reference level)
# 14   2011.0       Anoka  <6 years  >5 mcg/dL (current reference level)
# 15   2012.0       Anoka  <6 years  >5 mcg/dL (current reference level)
# 16   2013.0       Anoka  <6 years  >5 mcg/dL (current reference level)
# 17   2014.0       Anoka  <6 years  >5 mcg/dL (current reference level)
# 20   2017.0       Anoka  <6 years  >5 mcg/dL (current reference level)
# 134  2012.0      Dakota  <6 years  >5 mcg/dL (current reference level)
# 135  2013.0      Dakota  <6 years  >5 mcg/dL (current reference level)
# 136  2014.0      Dakota  <6 years  >5 mcg/dL (current reference level)
# 137  2015.0      Dakota  <6 years  >5 mcg/dL (current reference level)
# 138  2016.0      Dakota  <6 years  >5 mcg/dL (current reference level)
# 139  2017.0      Dakota  <6 years  >5 mcg/dL (current reference level)
# 189  2011.0    Hennepin  <6 years  >5 mcg/dL (current reference level)
# 190  2012.0    Hennepin  <6 years  >5 mcg/dL (current reference level)
# 191  2013.0    Hennepin  <6 years  >5 mcg/dL (current reference level)
# 192  2014.0    Hennepin  <6 years  >5 mcg/dL (current reference level)
# 193  2015.0    Hennepin  <6 years  >5 mcg/dL (current reference level)
# 194  2016.0    Hennepin  <6 years  >5 mcg/dL (current reference level)
# 195  2017.0    Hennepin  <6 years  >5 mcg/dL (current reference level)
# 244  2017.0   Kandiyohi  <6 years  >5 mcg/dL (current reference level)
# 434  2011.0      Ramsey  <6 years  >5 mcg/dL (current reference level)
# 435  2012.0      Ramsey  <6 years  >5 mcg/dL (current reference level)
# 436  2013.0      Ramsey  <6 years  >5 mcg/dL (current reference level)
# 437  2014.0      Ramsey  <6 years  >5 mcg/dL (current reference level)
# 438  2015.0      Ramsey  <6 years  >5 mcg/dL (current reference level)
# 439  2016.0      Ramsey  <6 years  >5 mcg/dL (current reference level)
# 440  2017.0      Ramsey  <6 years  >5 mcg/dL (current reference level)
# 466  2015.0        Rice  <6 years  >5 mcg/dL (current reference level)
# 483  2011.0   St. Louis  <6 years  >5 mcg/dL (current reference level)
# 484  2012.0   St. Louis  <6 years  >5 mcg/dL (current reference level)
# 486  2014.0   St. Louis  <6 years  >5 mcg/dL (current reference level)
# 487  2015.0   St. Louis  <6 years  >5 mcg/dL (current reference level)
# 488  2016.0   St. Louis  <6 years  >5 mcg/dL (current reference level)
# 489  2017.0   St. Louis  <6 years  >5 mcg/dL (current reference level)
# 574  2011.0  Washington  <6 years  >5 mcg/dL (current reference level)
#
#     pctEbll  numTested  numEbll  denominator  pctTested unstable
# 0       1.0    91344.0    926.0     425252.0       21.5    False
# 1       1.2    90585.0   1063.0     422537.0       21.4    False
# 2       1.0    89488.0    866.0     420715.0       21.3    False
# 3       0.8    89060.0    730.0     419965.0       21.2    False
# 4       0.9    87717.0    781.0     421429.0       20.8    False
# 5       1.0    89844.0    873.0     423100.0       21.2    False
# 6       0.8    92535.0    765.0     426490.0       21.7    False
# 14      0.4     6096.0     22.0      26540.0       23.0    False
# 15      0.6     6139.0     35.0      26154.0       23.5    False
# 16      0.4     6187.0     27.0      26030.0       23.8    False
# 17      0.3     6141.0     20.0      25988.0       23.6    False
# 20      0.4     6503.0     23.0      26564.0       24.5    False
# 134     0.4     6848.0     30.0      32894.0       20.8    False
# 135     0.6     6880.0     39.0      32652.0       21.1    False
# 136     0.3     6859.0     24.0      32629.0       21.0    False
# 137     0.4     6881.0     27.0      32612.0       21.1    False
# 138     0.5     7007.0     34.0      33025.0       21.2    False
# 139     0.3     7795.0     23.0      33283.0       23.4    False
# 189     1.7    21550.0    363.0      92209.0       23.4    False
# 190     1.9    21787.0    422.0      93320.0       23.3    False
# 191     1.5    21721.0    317.0      94382.0       23.0    False
# 192     1.1    21205.0    237.0      95231.0       22.3    False
# 193     1.2    21008.0    248.0      96689.0       21.7    False
# 194     1.2    21284.0    261.0      96545.0       22.0    False
# 195     1.0    21856.0    215.0      96833.0       22.6    False
# 244     2.8      893.0     25.0       3450.0       25.9    False
# 434     2.1    11917.0    250.0      42921.0       27.8    False
# 435     2.3    11648.0    264.0      43685.0       26.7    False
# 436     1.7    12122.0    209.0      44444.0       27.3    False
# 437     1.4    11748.0    166.0      45045.0       26.1    False
# 438     1.5    11650.0    169.0      45614.0       25.5    False
# 439     2.1    11905.0    254.0      45684.0       26.1    False
# 440     1.5    12207.0    185.0      45707.0       26.7    False
# 466     1.7     1243.0     21.0       4417.0       28.1    False
# 483     0.6     3226.0     20.0      12940.0       24.9    False
# 484     0.9     3241.0     29.0      12747.0       25.4    False
# 486     0.7     3061.0     20.0      12431.0       24.6    False
# 487     0.7     3073.0     22.0      12371.0       24.8    False
# 488     0.7     3131.0     21.0      12278.0       25.5    False
# 489     1.4     3000.0     42.0      12249.0       24.5    False
# 574     0.7     3435.0     23.0      18773.0       18.3    False

# %%
rfdf=rrdf.dropna()

# %%
xz=rfdf['pctEbll'].astype(float)
rfdf['xz']=xz
r

# %%
rfdf.columns
# Out:
# Index(['year', 'location', 'ageGroup', 'ebllDescription', 'pctEbll',
#        'numTested', 'numEbll', 'denominator', 'pctTested', 'unstable', 'xz'],
#       dtype='object')

# %%
rfdf.loc[:, ['year', 'location', 'ebllDescription',
       'pctEbll',  'numTested', 'numEbll', 'denominator', 'pctTested']]
# Out:
#        year    location                      ebllDescription pctEbll  \
# 0    2011.0   Minnesota  >5 mcg/dL (current reference level)     1.0
# 1    2012.0   Minnesota  >5 mcg/dL (current reference level)     1.2
# 2    2013.0   Minnesota  >5 mcg/dL (current reference level)     1.0
# 3    2014.0   Minnesota  >5 mcg/dL (current reference level)     0.8
# 4    2015.0   Minnesota  >5 mcg/dL (current reference level)     0.9
# 5    2016.0   Minnesota  >5 mcg/dL (current reference level)     1.0
# 6    2017.0   Minnesota  >5 mcg/dL (current reference level)     0.8
# 14   2011.0       Anoka  >5 mcg/dL (current reference level)     0.4
# 15   2012.0       Anoka  >5 mcg/dL (current reference level)     0.6
# 16   2013.0       Anoka  >5 mcg/dL (current reference level)     0.4
# 17   2014.0       Anoka  >5 mcg/dL (current reference level)     0.3
# 20   2017.0       Anoka  >5 mcg/dL (current reference level)     0.4
# 134  2012.0      Dakota  >5 mcg/dL (current reference level)     0.4
# 135  2013.0      Dakota  >5 mcg/dL (current reference level)     0.6
# 136  2014.0      Dakota  >5 mcg/dL (current reference level)     0.3
# 137  2015.0      Dakota  >5 mcg/dL (current reference level)     0.4
# 138  2016.0      Dakota  >5 mcg/dL (current reference level)     0.5
# 139  2017.0      Dakota  >5 mcg/dL (current reference level)     0.3
# 189  2011.0    Hennepin  >5 mcg/dL (current reference level)     1.7
# 190  2012.0    Hennepin  >5 mcg/dL (current reference level)     1.9
# 191  2013.0    Hennepin  >5 mcg/dL (current reference level)     1.5
# 192  2014.0    Hennepin  >5 mcg/dL (current reference level)     1.1
# 193  2015.0    Hennepin  >5 mcg/dL (current reference level)     1.2
# 194  2016.0    Hennepin  >5 mcg/dL (current reference level)     1.2
# 195  2017.0    Hennepin  >5 mcg/dL (current reference level)     1.0
# 244  2017.0   Kandiyohi  >5 mcg/dL (current reference level)     2.8
# 434  2011.0      Ramsey  >5 mcg/dL (current reference level)     2.1
# 435  2012.0      Ramsey  >5 mcg/dL (current reference level)     2.3
# 436  2013.0      Ramsey  >5 mcg/dL (current reference level)     1.7
# 437  2014.0      Ramsey  >5 mcg/dL (current reference level)     1.4
# 438  2015.0      Ramsey  >5 mcg/dL (current reference level)     1.5
# 439  2016.0      Ramsey  >5 mcg/dL (current reference level)     2.1
# 440  2017.0      Ramsey  >5 mcg/dL (current reference level)     1.5
# 466  2015.0        Rice  >5 mcg/dL (current reference level)     1.7
# 483  2011.0   St. Louis  >5 mcg/dL (current reference level)     0.6
# 484  2012.0   St. Louis  >5 mcg/dL (current reference level)     0.9
# 486  2014.0   St. Louis  >5 mcg/dL (current reference level)     0.7
# 487  2015.0   St. Louis  >5 mcg/dL (current reference level)     0.7
# 488  2016.0   St. Louis  >5 mcg/dL (current reference level)     0.7
# 489  2017.0   St. Louis  >5 mcg/dL (current reference level)     1.4
# 574  2011.0  Washington  >5 mcg/dL (current reference level)     0.7
#
#      numTested  numEbll  denominator  pctTested
# 0      91344.0    926.0     425252.0       21.5
# 1      90585.0   1063.0     422537.0       21.4
# 2      89488.0    866.0     420715.0       21.3
# 3      89060.0    730.0     419965.0       21.2
# 4      87717.0    781.0     421429.0       20.8
# 5      89844.0    873.0     423100.0       21.2
# 6      92535.0    765.0     426490.0       21.7
# 14      6096.0     22.0      26540.0       23.0
# 15      6139.0     35.0      26154.0       23.5
# 16      6187.0     27.0      26030.0       23.8
# 17      6141.0     20.0      25988.0       23.6
# 20      6503.0     23.0      26564.0       24.5
# 134     6848.0     30.0      32894.0       20.8
# 135     6880.0     39.0      32652.0       21.1
# 136     6859.0     24.0      32629.0       21.0
# 137     6881.0     27.0      32612.0       21.1
# 138     7007.0     34.0      33025.0       21.2
# 139     7795.0     23.0      33283.0       23.4
# 189    21550.0    363.0      92209.0       23.4
# 190    21787.0    422.0      93320.0       23.3
# 191    21721.0    317.0      94382.0       23.0
# 192    21205.0    237.0      95231.0       22.3
# 193    21008.0    248.0      96689.0       21.7
# 194    21284.0    261.0      96545.0       22.0
# 195    21856.0    215.0      96833.0       22.6
# 244      893.0     25.0       3450.0       25.9
# 434    11917.0    250.0      42921.0       27.8
# 435    11648.0    264.0      43685.0       26.7
# 436    12122.0    209.0      44444.0       27.3
# 437    11748.0    166.0      45045.0       26.1
# 438    11650.0    169.0      45614.0       25.5
# 439    11905.0    254.0      45684.0       26.1
# 440    12207.0    185.0      45707.0       26.7
# 466     1243.0     21.0       4417.0       28.1
# 483     3226.0     20.0      12940.0       24.9
# 484     3241.0     29.0      12747.0       25.4
# 486     3061.0     20.0      12431.0       24.6
# 487     3073.0     22.0      12371.0       24.8
# 488     3131.0     21.0      12278.0       25.5
# 489     3000.0     42.0      12249.0       24.5
# 574     3435.0     23.0      18773.0       18.3

# %%
# DTV=MCTD.groupby(['Drug','Timepoint'])
# # Convert to DataFrame
# DTVdf=pd.DataFrame(DTV['Tumor Volume (mm3)'].mean())
# # Preview DataFrame
# DTVdf=DTVdf.reset_index()

rfdfg=rfdf.groupby(['location']).mean()

# %%
ll=rfdfg.index
mn=['Minnesota']
for item in ll:
    if item != 'Minnesota':
        mn.append(item)
sorterIndex = dict(zip(mn,range(len(mn))))
# print(sorterIndex)
rfdfg['mn_Rank'] = rfdfg.index.map(sorterIndex)

# df.sort(['Tm_Rank', 'Player', 'Year'], \
#         ascending = [True , True, True], inplace = True)
# rfdfg.reset_index()
rfdfg=rfdfg.sort_values(['mn_Rank'])

# %%
# nz=newsmean_df.reset_index()
# x=rfdfg.pivot(index='columns='location')['numEbll']

# %%
x=rfdfg.index
cp=rfdfg['xz']




# Bar chart properties
plt.title('Elevated lead levels in childer 6 and under in MN counties')
plt.xlabel('Minnesota VS MN counties').set_color("gray")
plt.ylabel('% Elevated Pb Blood Level')
bars = plt.bar(x, cp, align='center',edgecolor='black')
bars[0].set_facecolor('Red')
bars[1].set_facecolor('orange')
bars[2].set_facecolor('yellow')
bars[3].set_facecolor('green')
bars[4].set_facecolor('blue')
bars[5].set_facecolor('violet')
bars[6].set_facecolor('lightgreen')
bars[7].set_facecolor('lightblue')
bars[8].set_facecolor('darkblue')
plt.xticks(x, rotation=90)

plt.gca().get_xticklabels()[0].set_color("red")

plt.savefig('Elevated lead levels in childer 6 and under in MN counties.png',dpi=300, bbox_inches = "tight")
plt.show

# # Save the Figure
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
