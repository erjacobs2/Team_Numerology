# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import style
style.use('ggplot')

# %%
file = 'Poverty (2011-2016) master data.csv'
poverty_df = pd.read_csv(file)
poverty_df
# Out:
#      Year  State  County ID          County Name (State)  \
# 0    2011     27      27001           Aitkin County (MN)
# 1    2011     27      27003            Anoka County (MN)
# 2    2011     27      27005           Becker County (MN)
# 3    2011     27      27007         Beltrami County (MN)
# 4    2011     27      27009           Benton County (MN)
# 5    2011     27      27011        Big Stone County (MN)
# 6    2011     27      27013       Blue Earth County (MN)
# 7    2011     27      27015            Brown County (MN)
# 8    2011     27      27017          Carlton County (MN)
# 9    2011     27      27019           Carver County (MN)
# 10   2011     27      27021             Cass County (MN)
# 11   2011     27      27023         Chippewa County (MN)
# 12   2011     27      27025          Chisago County (MN)
# 13   2011     27      27027             Clay County (MN)
# 14   2011     27      27029       Clearwater County (MN)
# ...

# %%
new_poverty_df = poverty_df[['Year','County Name (State)','Under Age 18 in Poverty Count','Under Age 18 in Poverty Percent']]
new_poverty_df
# Out:
#      Year          County Name (State) Under Age 18 in Poverty Count  \
# 0    2011           Aitkin County (MN)                           640
# 1    2011            Anoka County (MN)                         9,323
# 2    2011           Becker County (MN)                         1,595
# 3    2011         Beltrami County (MN)                         3,280
# 4    2011           Benton County (MN)                         1,320
# 5    2011        Big Stone County (MN)                           225
# 6    2011       Blue Earth County (MN)                         2,100
# 7    2011            Brown County (MN)                           631
# 8    2011          Carlton County (MN)                         1,074
# 9    2011           Carver County (MN)                         1,678
# 10   2011             Cass County (MN)                         1,758
# 11   2011         Chippewa County (MN)                           455
# 12   2011          Chisago County (MN)                         1,171
# ...

# %%
new_poverty_df.to_csv("Under 18 in Poverty (2011-2016)", index=False, header=True)
